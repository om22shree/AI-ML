# %% [markdown]
# ### Question

# %%
## Introduction
    - For this assignment, read the scenario below and then respond to the problem statement described.
    
## Scenario
    - You are required to design the data structure to display the individual player stats for cricket players.
    A player may have represented more than one team and may have played in more than one format such as Test, ODI and T20.

## Problem Statement
    - Create a list of different data fields and use appropriate Python data types to represent each of them.
    
### Assignment Submission
    - You can use the table format displayed below for your response. You can add additional columns of information if 
    you want. Create a document/pdf of your response and upload a zip file using the Progress Tracker.
    
Data field identifier      Data type       Example        Your reason for using this data type
    1. player_name          String        Virat Kohli      Names may contain letters and any other characters.
    2.
    3.
    4.
    5.


### Learning outcomes being evaluated
    • Distinguish between different data types.
    • Use recommended conventions for naming variables.

# %% [markdown]
# ### Question

# %%
# Ques: 
## Introduction
    - For this assignment, read the scenario below and then respond to the problem statement described.

## Scenario
    - The 'Man of the Match' award of a 50-over cricket match is decided by computing points earned by players. You have 
    given a table of batsmans. Your task to help to select the man of the match by given some answers.

## Problem Statement   
    - You are given a table of cricket players. These table represent only the batsman. Your task to select the data type 
    to store these data and also perform these operations..
        - Your task is to find the batsman who score highest runs and display run and batsman names.
        - Your task is to find the batsman who score highest sixes and display run and batsman names.
        - Your task is to find the batsman who score lowest runs and display run and batsman names.
        - Your task is to find the batsman who takes highest balls and display run and batsman names.
        - Your task is to find the Total runs which is score by the batsmans.

## Table:
   Name         Role        Runs        4        6       balls        field/catchs
Virat Kohli     Batting     112         10       2        102           0
du Plessis      Batting     78          6        7        89            1
S Raina         Batting     92          3        5        68            2
M S Dhoni       Batting     94          7        9        80            2
K L Rahul       Batting     108         6        5        90            1
Rohit Sharma    Batting     98          3        8        110           0
.
.
. ## You can add more..


## Input Format: 
    - Enter the all data which is on the table using the python dataTpye.

## Output Format:
    - Your task is to find the batsman who score highest runs and display run and batsman names.
    - Your task is to find the batsman who score highest sixes and display run and batsman names.
    - Your task is to find the batsman who score lowest runs and display run and batsman names.
    - Your task is to find the batsman who takes highest balls and display run and batsman names.
    - Display the total runs which is score by the batsmans.

## Sample Output:
    1. Virat Kohli : 112 runs
    2. M S Dhoni : 9 sixes ..

# %% [markdown]
# ### Question

# %%
## Introduction
    - For this assignment, read the scenario below and then respond to the problem statement described.
    
## Scenario
    - The persons of different Country speak to English, Hindi, French and Chinese. Some persons only speak English, Hindi, 
    French and Chinese, some persons only speak two languages like Hindi and English etc. Some persons speak three languages 
    and some persons speak all language.

## Problem Statement   
    - You are given 4 sets of persons ids. These sets represent only those who speak their languages. The same persons 
    could be in all sets and only two, three sets.
        - Your task is to find the total number of persons who have known to at least one language.
        - Your task is to find the total number of persons who have known to any two language.
        - Your task is to find the total number of persons who have known to all language.
        - Your task is to find the total number of persons who have known to only English language.

## Input Format:
    - The first line contains an integer, EN the number of persons who have known to the English languages.
    - The second line contains EN space separated ID numbers of those persons.
    - The first line contains an integer, HN the number of persons who have known to the English languages.
    - The second line contains HN space separated ID numbers of those persons.
    - The first line contains an integer, FN the number of persons who have known to the English languages.
    - The second line contains FN space separated ID numbers of those persons.
    - The first line contains an integer, CN the number of persons who have known to the English languages.
    - The second line contains CN space separated ID numbers of those persons.

## Output Format:
    - Total number of persons who have known to at least one language.
    - Total number of persons who have known to any two language.
    - Total number of persons who have known to all language.
    - Total number of persons who have known to only English language.

## Example
## Sample Input:
    EN -> 17
    EN number Student -> 121 1 2 3 4 5 6 7 8 9 98 78 56 12 23 43 100
    HN -> 16
    HN number Student -> 123 10 1 2 3 11 21 55 6 8 34 12 45 76 89 100
    FN -> 18
    FN number Student -> 1 2 23 3 4 5 6 7 8 9 56 76 87 98 23 12 44 100
    CN -> 17
    CN number Student -> 10 1 22 2 3 11 21 55 6 8 34 12 34 56 87 671 100

## Sample Output:
    - Total number of persons who have known least One Language : xxxx
    - Total number of persons who have known any two Language : xxxx
    - Total number of persons who have known all Language : xxxx
    - Total number of persons who have known only English Language : xxxx

# %% [markdown]
# ### Question

# %%
## Introduction
    - For this assignment, read the scenario below and then respond to the problem statement described.
    
## Scenario
    - You have a test data which is given the speech by Joe Biden in 2017. The speech on The Cancer Moonshot. Over task to 
    find the summary of this speech. What is the main points which is highlight in this speech. This is done by RNN deep 
    learning method.  

## Problem Statement   
    - You are given the text data your task to preprocess this data for text summarization. Your task is to preform these
    setps for text preprocessing. 
    Tasks:
        1. Remove all the comma (,) in this paragraph.
        2. Remove all the dots (.) in this paragraph.
        3. Remove all the stopwords like "and","a","the","in","of","is","on","did","to","at",'\n'.
        4. Print the remaining paragraph. 

paragraph : """THE VICE PRESIDENT:  Madam Ambassador, thanks for putting together a crowd for us.  (Laughter.) \nFolks, 
I’m delighted to be here and happy to be back with so many distinguished people.  And I mean that sincerely.  Many of you
know as much or more about the subjects I’m going to speak to than I do, including -- is Elizabeth Blackburn here?  
Elizabeth, a Nobel Laureate, who found the BRCA gene.  As that old saying goes, she’s forgotten more about this than I’m 
going to know.\nBut, folks, I’m happy to be back here at the World Economic Forum at Davos to talk about the fight against
cancer.  And I’m accompanied by Greg Simon, who is Executive Director of administration’s Cancer Moonshot and who will lead
my Biden Cancer Initiative that I’ll launch after we leave office, which is in about 48 hours.  (Laughter.)  I hope I have
a ride home.  (Laughter.)  I’ll talk about in a few moments.\nBut, Greg, where are you?  Greg has had a great deal of 
experience in this area and he’s led the initiative the last year for the President and me. Last year, I arrived at the 
forum a few days after President Obama delivered his final State of the Union Address, where he announced, quite frankly to
my surprise, that he was putting me in charge of a national Cancer Moonshot to double the rate of progress in preventing, 
diagnosing and treating cancer.\nAnd I was not only genuinely surprised by the announcement, I was genuinely surprised by
the response that I got both at home and abroad.  Here at Davos I was scheduled -- Klaus had asked me to deliver the 
keynote address on the promise and perils of the Fourth Industrial Revolution, and to participate in a few bilateral
meetings over the remaining days.But given the overwhelming interest in the Cancer Moonshot, the forum asked  me if I 
could quickly convene a roundtable of cancer experts, among whom Elizabeth was one of them, to discuss where we are and
where we need to go in the fight against cancer.\n\nAnd so I did on a few days notice we put together such a roundtable
and it kicked off what for me was a year-long journey that’s taken me literally around the world meeting with the best
cancer researchers, doctors, nurses, and patients, as well as philanthropists, heads of state -- they've all been part of
it. \n\nBut I’m back here today to outline how far we’ve come and what -- at least from our perspective -- what path we 
should chart moving forward.\n\nAnd let me start with where we believe we are.  When we announced the Cancer Moonshot, 
I knew there would be a lot of skeptics out there who’d say, “well, here we go again. Haven’t we done this before?”  
\n\nPresident Nixon, when he declared War on Cancer in 1971, he was earnest and sincere and very committed.  But what
makes the difference between then and now is -- the single big difference is that he had no army.  He had no resources.
He had no weapons.  He had no strategy to win.  \n\nBut after 45 years with many of you in this room doing incredible work,
45 years of progress, after decades of funding research, training scientists and physicians, treating millions of patients,
we now have an army.  We now have powerful new technologies and tools, like:  Immunotherapy that -- by the way, even six, 
eight, 10 years ago was viewed kind of as a voodoo science out there.  It wasn’t really an integral part of this fight -- 
that makes cancer cells visible to the immune system so our natural defenses can destroy the cancer. \n\nSurgeons are using
cutting-edge robotics to allow for more precise imaging to find the cancer and more precisely surgically remove the cancer 
in hard-to-reach areas.\n\nLiquid biopsies that find early signs of cancer in the blood and tell you whether or not you 
have a particular cancer.    \n\nThese advances and many others provide hope that more precise medicines and diagnostics
might greatly improve and detect and defeat cancer.  \n\nBut on so many levels, we’ve now reached an inflection point. 
When the system was set up before, we thought there was basically only one cancer in different parts of the body.  We’ve
now learned there are over 200 specific kinds of cancers.\n\nAfter decades we thought we could tackle cancer one discipline
at a time.  But thats not how cancer operates.  Cancer uses every tool at its disposal -- it hides from the immune system, 
it builds it own blood supply system, it uses viruses to spread, it engineers a friendlier environment, a cellular 
environment in which to survive.\n\nAnd it knows how to spread through the body using pathways and mutations we don’t 
understand fully yet.  And cancer never gives up, it never surrenders.  That's why we have to use every discipline cancer
does, and that's what we’re starting to in a way that's only really begun in the last five or six, seven years.\n\nFive
years ago as I said, oncologists weren’t routinely working closely with immunologists, virologists, geneticists, chemical
and biological engineers.  And now they are. \n\nImmunotherapies are finding the keys to making cancer cells visible and 
targeting them.  Virologist are now working on vaccines to prevent and treat cancers. Geneticists are cataloging mutations
that drive cancers.  And chemical and biological engineers are helping engineer environments hostile to cancer.  
And they’re all working together.\n\nLike many of you, I decided to become acquainted with this after someone close to
me in my family was diagnosed.  You tend to try to learn everything you possibly can once that occurs.  And I knew little 
about the discipline.  And like I said, what impressed me was that so much of this is really very brand new in terms of the
collaboration."""
    
## Output Format:
    - Display the preprocessed text speach data which is useful for RNN.

# %% [markdown]
# ### Question

# %%
## Introduction
    - For this assignment, read the scenario below and then respond to the problem statement
    described.

##Scenario
    - The 'Man of the Match' award of a 50-over cricket match is decided by computing points earned by players. The points 
    are calculated on the basis of the following rules:
    ## Batting
        • Each 1 point for 2 runs scored
        • Additional 5 points for half century
        • Additional 10 points for century
        • Each 1 point for hitting a boundary (four) and Each 2 points for over boundary (six)
        • If the strick rate 100% or grater then add 10 points more.
        • 5 points for fielding/catchs.
    
    ##Bowling
        • 10 points for each wicket
        • Additional 5 points for two wickets per innings
        • 4 points for economy rate (runs given per over) between 3.5 and 4.5
        • 7 points for economy rate between 3 and 5.5
        • 5 points for fielding/catchs.
    
    ##Fielding
        • 10 points each for catch/stumping/run out
        
## Problem Statement 
    You need to find the man of the match so for finding the man of the match preform these task:
        - Your task to using these batting, bowling and Fielding Scenario calculate the points of all the players. 
        - Display the Lowest and Highest players points along with there name.
    
## Input Data :
    The performance of each player is stored in a dictionary object. Displayed below is data for 5 players.
        p1={'name':'Virat Kohli', 'role':'bat', 'runs':112, '2':8,'4':10, '6':5, 'balls':109, 'field':0}
        p2={'name':'du Plessis', 'role':'bat', 'runs':120,'2':3, '4':3, '6':8,'balls':112, 'field':0}
        p3={'name':'Bhuvneshwar Kumar', 'role':'bowl', 'wkts':1, 'overs':10,'runs':71, 'field':1}
        p4={'name':'Yuzvendra Chahal', 'role':'bowl', 'wkts':2, 'overs':10, 'runs':45, 'field':0}
        p5={'name':'Kuldeep Yadav', 'role':'bowl', 'wkts':3, 'overs':10, 'runs':34,'field':0}
    
## Output Format:
    - Your task to using these batting, bowling and Fielding Scenario calculate the points of all the players. 
    - Display the Lowest and Highest players points along with there name.

## Example: 
    Virat Kohli : 53 points
    du Plessis  : 47 points.. etc
